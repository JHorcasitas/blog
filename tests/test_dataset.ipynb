# %%
import sys
sys.path.append('..')

# %%
from ImageNet.dataset import ImageNetDataset
from ImageNet import config

# %% [markdown]
# ### No transformation

# %%
d = ImageNetDataset(kind='train')

# %%
d[0][0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x1FDDA3290B8>

# %%
d[0][1]
# Out:
# '449'

# %%
type(d[0][1])
# Out:
# str

# %% [markdown]
# ### With transformation

# %%
d = ImageNetDataset(kind='train', transform=config.default_transform)

# %%
(d[0][0]).shape, (d[0][0]).dtype
# Out:
# (torch.Size([3, 224, 224]), torch.float32)

# %%
d[0][1], d[0][1].dtype
# Out:
# (array(449., dtype=float32), dtype('float32'))
